# %% [markdown]
# # 👋 გამარჯობა! Welcome to Tbilisi Hack Club!

# %% [markdown]
# Hey there, hacker! We are incredibly excited to have you here.
#
# Tbilisi Hack Club is a community built *by* students, *for* students in our amazing city. This is a place where you can let your curiosity run wild. We're here to tinker, to build, to break, and to create amazing things with code. Whether you've built 100 apps or are just writing your first `print('Hello, World!')`, you belong here with us.

# %% [markdown]
# ## Our Philosophy: Learn by Building
#
# We don't do boring lectures. The best way to learn is by getting your hands dirty and building something real. Have an idea for a game, a website, a robot, or something no one has ever thought of before? This is the place to make it happen. You bring the ideas, and we'll provide the space, the support, and the community to help you bring them to life.

# %%
# Every great journey starts with a single line of code.
# This is a Python code cell. You can run this code in a real Jupyter environment!

club_name = "Tbilisi Hack Club"
message = f"Long live {club_name}! გაუმარჯოს!"

print(message)

# %% [markdown]
# ## 💬 Stay Connected
#
# Join the conversation and see what other hackers are building. Find us online and say hi!
#
# - **GitHub:** [github.com/tbilisihc](https://github.com/tbilisihc)
# - **Twitter:** [@tbilisihc](https://twitter.com/tbilisi_hc)
# - **Instagram:** [@tbilisihc](https://instagram.com/tbilisihc)
#
# Don't be a stranger. We can't wait to see what you create. Let's get started!
